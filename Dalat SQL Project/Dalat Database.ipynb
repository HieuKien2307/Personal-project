-- %% [markdown]
-- # [Dalat]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Dalat]    Script Date: 3/2/2023 9:06:09 PM ******/
CREATE DATABASE [Dalat]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Dalat', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Dalat.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Dalat_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Dalat_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Dalat] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Dalat].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Dalat] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Dalat] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Dalat] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Dalat] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Dalat] SET ARITHABORT OFF 
GO
ALTER DATABASE [Dalat] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Dalat] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Dalat] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Dalat] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Dalat] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Dalat] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Dalat] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Dalat] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Dalat] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Dalat] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Dalat] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Dalat] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Dalat] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Dalat] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Dalat] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Dalat] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Dalat] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Dalat] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Dalat] SET  MULTI_USER 
GO
ALTER DATABASE [Dalat] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Dalat] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Dalat] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Dalat] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Dalat] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Dalat] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Dalat] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[guest]

-- %%
USE [Dalat]
GO

-- %%
/****** Object:  Table [dbo].[guest]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[guest](
	[ID] [nvarchar](10) NOT NULL,
	[first_name] [nvarchar](80) NULL,
	[last_name] [nvarchar](80) NULL,
	[phone_number] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[hosted_at]

-- %%
/****** Object:  Table [dbo].[hosted_at]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[hosted_at](
	[ID] [nvarchar](10) NOT NULL,
	[guest_id] [nvarchar](10) NULL,
	[occupied_room_id] [nvarchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Hotel]

-- %%
/****** Object:  Table [dbo].[Hotel]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hotel](
	[ID] [nvarchar](11) NOT NULL,
	[name] [nvarchar](40) NULL,
	[address] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[occupied_room]

-- %%
/****** Object:  Table [dbo].[occupied_room]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[occupied_room](
	[ID] [nvarchar](10) NOT NULL,
	[check_in] [datetime] NULL,
	[check_out] [datetime] NULL,
	[room_id] [nvarchar](10) NOT NULL,
	[reservation_id] [nvarchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[reservation]

-- %%
/****** Object:  Table [dbo].[reservation]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[reservation](
	[ID] [nvarchar](10) NOT NULL,
	[date_in] [datetime] NULL,
	[date_out] [datetime] NULL,
	[guest_id] [nvarchar](10) NULL,
	[deposit] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[reserved_room]

-- %%
/****** Object:  Table [dbo].[reserved_room]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[reserved_room](
	[ID] [nvarchar](10) NOT NULL,
	[number_of_rooms] [int] NULL,
	[room_type_id] [nvarchar](10) NULL,
	[reservation_id] [nvarchar](10) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[room]

-- %%
/****** Object:  Table [dbo].[room]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[room](
	[ID] [nvarchar](10) NOT NULL,
	[hotel_id] [nvarchar](11) NULL,
	[status] [nvarchar](40) NULL,
	[smoke] [nvarchar](5) NULL,
	[room_type_id] [nvarchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[room_type]

-- %%
/****** Object:  Table [dbo].[room_type]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[room_type](
	[ID] [nvarchar](10) NOT NULL,
	[description] [nvarchar](80) NULL,
	[max_capacity] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[staff]

-- %%
/****** Object:  Table [dbo].[staff]    Script Date: 3/2/2023 9:06:09 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[staff](
	[ID] [nvarchar](10) NOT NULL,
	[hotel_id] [nvarchar](11) NOT NULL,
	[level] [int] NULL,
	[first_name] [nvarchar](10) NULL,
	[last_name] [nvarchar](20) NULL,
	[birthday] [datetime] NULL,
	[manager_id] [nvarchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC,
	[hotel_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [fk_5]

-- %%
ALTER TABLE [dbo].[hosted_at]  WITH CHECK ADD  CONSTRAINT [fk_5] FOREIGN KEY([occupied_room_id])
REFERENCES [dbo].[occupied_room] ([ID])
GO
ALTER TABLE [dbo].[hosted_at] CHECK CONSTRAINT [fk_5]
GO

-- %% [markdown]
-- # [fk_6]

-- %%
ALTER TABLE [dbo].[hosted_at]  WITH CHECK ADD  CONSTRAINT [fk_6] FOREIGN KEY([guest_id])
REFERENCES [dbo].[guest] ([ID])
GO
ALTER TABLE [dbo].[hosted_at] CHECK CONSTRAINT [fk_6]
GO

-- %% [markdown]
-- # [fk_4]

-- %%
ALTER TABLE [dbo].[occupied_room]  WITH CHECK ADD  CONSTRAINT [fk_4] FOREIGN KEY([room_id])
REFERENCES [dbo].[room] ([ID])
GO
ALTER TABLE [dbo].[occupied_room] CHECK CONSTRAINT [fk_4]
GO

-- %% [markdown]
-- # [fk_8]

-- %%
ALTER TABLE [dbo].[occupied_room]  WITH CHECK ADD  CONSTRAINT [fk_8] FOREIGN KEY([reservation_id])
REFERENCES [dbo].[reservation] ([ID])
GO
ALTER TABLE [dbo].[occupied_room] CHECK CONSTRAINT [fk_8]
GO

-- %% [markdown]
-- # [fk_7]

-- %%
ALTER TABLE [dbo].[reservation]  WITH CHECK ADD  CONSTRAINT [fk_7] FOREIGN KEY([guest_id])
REFERENCES [dbo].[guest] ([ID])
GO
ALTER TABLE [dbo].[reservation] CHECK CONSTRAINT [fk_7]
GO

-- %% [markdown]
-- # [fk_1]

-- %%
ALTER TABLE [dbo].[reserved_room]  WITH CHECK ADD  CONSTRAINT [fk_1] FOREIGN KEY([reservation_id])
REFERENCES [dbo].[reservation] ([ID])
GO
ALTER TABLE [dbo].[reserved_room] CHECK CONSTRAINT [fk_1]
GO

-- %% [markdown]
-- # [fk_2]

-- %%
ALTER TABLE [dbo].[reserved_room]  WITH CHECK ADD  CONSTRAINT [fk_2] FOREIGN KEY([room_type_id])
REFERENCES [dbo].[room_type] ([ID])
GO
ALTER TABLE [dbo].[reserved_room] CHECK CONSTRAINT [fk_2]
GO

-- %% [markdown]
-- # [fk_3]

-- %%
ALTER TABLE [dbo].[room]  WITH CHECK ADD  CONSTRAINT [fk_3] FOREIGN KEY([room_type_id])
REFERENCES [dbo].[room_type] ([ID])
GO
ALTER TABLE [dbo].[room] CHECK CONSTRAINT [fk_3]
GO

-- %% [markdown]
-- # [fk_9]

-- %%
ALTER TABLE [dbo].[room]  WITH CHECK ADD  CONSTRAINT [fk_9] FOREIGN KEY([hotel_id])
REFERENCES [dbo].[Hotel] ([ID])
GO
ALTER TABLE [dbo].[room] CHECK CONSTRAINT [fk_9]
GO

-- %% [markdown]
-- # [fk_10]

-- %%
ALTER TABLE [dbo].[staff]  WITH CHECK ADD  CONSTRAINT [fk_10] FOREIGN KEY([hotel_id])
REFERENCES [dbo].[Hotel] ([ID])
GO
ALTER TABLE [dbo].[staff] CHECK CONSTRAINT [fk_10]
GO

-- %% [markdown]
-- # [fk_11]

-- %%
ALTER TABLE [dbo].[staff]  WITH CHECK ADD  CONSTRAINT [fk_11] FOREIGN KEY([manager_id], [hotel_id])
REFERENCES [dbo].[staff] ([ID], [hotel_id])
GO
ALTER TABLE [dbo].[staff] CHECK CONSTRAINT [fk_11]
GO

-- %% [markdown]
-- # [Dalat]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Dalat] SET  READ_WRITE 
GO
